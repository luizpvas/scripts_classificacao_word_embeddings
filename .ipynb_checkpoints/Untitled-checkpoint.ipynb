# %%
import json

# %%
source = "{\"exception\":\"[object] (Illuminate\Database\QueryException(code: HY000): SQLSTATE[HY000]: General error: 1215 Cannot add foreign key constraint (SQL: alter table `search_hits` add constraint `search_hits_bot_session_id_foreign` foreign key (`bot_session_id`) references `bot_sessions` (`id`) on delete cascade) at /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php:664, PDOException(code: HY000): SQLSTATE[HY000]: General error: 1215 Cannot add foreign key constraint at /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php:458)[stacktrace]#0 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php(624): Illuminate\Database\Connection->runQueryCallback('alter table `se...', Array, Object(Closure))#1 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php(459): Illuminate\Database\Connection->run('alter table `se...', Array, Object(Closure))#2 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Schema/Blueprint.php(97): Illuminate\Database\Connection->statement('alter table `se...')#3 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Schema/Builder.php(264): Illuminate\Database\Schema\Blueprint->build(Object(Illuminate\Database\MySqlConnection), Object(Illuminate\Database\Schema\Grammars\MySqlGrammar))#4 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Schema/Builder.php(165): Illuminate\Database\Schema\Builder->build(Object(Illuminate\Database\Schema\Blueprint))#5 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Support/Facades/Facade.php(223): Illuminate\Database\Schema\Builder->create('search_hits', Object(Closure))#6 /home/luiz/Projects/laravel/docintent/database/migrations/2018_11_25_284443_create_search_hits_table.php(34): Illuminate\Support\Facades\Facade::__callStatic('create', Array)#7 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Migrations/Migrator.php(360): CreateSearchHitsTable->up()#8 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Migrations/Migrator.php(367): Illuminate\Database\Migrations\Migrator->Illuminate\Database\Migrations\{closure}()#9 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Migrations/Migrator.php(178): Illuminate\Database\Migrations\Migrator->runMigration(Object(CreateSearchHitsTable), 'up')#10 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Migrations/Migrator.php(147): Illuminate\Database\Migrations\Migrator->runUp('/home/luiz/Proj...', 1, false)#11 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Migrations/Migrator.php(96): Illuminate\Database\Migrations\Migrator->runPending(Array, Array)#12 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Console/Migrations/MigrateCommand.php(71): Illuminate\Database\Migrations\Migrator->run(Array, Array)#13 [internal function]: Illuminate\Database\Console\Migrations\MigrateCommand->handle()#14 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(29): call_user_func_array(Array, Array)#15 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(87): Illuminate\Container\BoundMethod::Illuminate\Container\{closure}()#16 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(31): Illuminate\Container\BoundMethod::callBoundMethod(Object(Illuminate\Foundation\Application), Array, Object(Closure))#17 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/Container.php(572): Illuminate\Container\BoundMethod::call(Object(Illuminate\Foundation\Application), Array, Array, NULL)#18 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Command.php(183): Illuminate\Container\Container->call(Array)#19 /home/luiz/Projects/laravel/docintent/vendor/symfony/console/Command/Command.php(255): Illuminate\Console\Command->execute(Object(Symfony\Component\Console\Input\ArrayInput), Object(Illuminate\Console\OutputStyle))#20 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Command.php(170): Symfony\Component\Console\Command\Command->run(Object(Symfony\Component\Console\Input\ArrayInput), Object(Illuminate\Console\OutputStyle))#21 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Command.php(198): Illuminate\Console\Command->run(Object(Symfony\Component\Console\Input\ArrayInput), Object(Illuminate\Console\OutputStyle))#22 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Console/Migrations/FreshCommand.php(55): Illuminate\Console\Command->call('migrate', Array)#23 [internal function]: Illuminate\Database\Console\Migrations\FreshCommand->handle()#24 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(29): call_user_func_array(Array, Array)#25 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(87): Illuminate\Container\BoundMethod::Illuminate\Container\{closure}()#26 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/BoundMethod.php(31): Illuminate\Container\BoundMethod::callBoundMethod(Object(Illuminate\Foundation\Application), Array, Object(Closure))#27 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Container/Container.php(572): Illuminate\Container\BoundMethod::call(Object(Illuminate\Foundation\Application), Array, Array, NULL)#28 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Command.php(183): Illuminate\Container\Container->call(Array)#29 /home/luiz/Projects/laravel/docintent/vendor/symfony/console/Command/Command.php(255): Illuminate\Console\Command->execute(Object(Symfony\Component\Console\Input\ArgvInput), Object(Illuminate\Console\OutputStyle))#30 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Command.php(170): Symfony\Component\Console\Command\Command->run(Object(Symfony\Component\Console\Input\ArgvInput), Object(Illuminate\Console\OutputStyle))#31 /home/luiz/Projects/laravel/docintent/vendor/symfony/console/Application.php(886): Illuminate\Console\Command->run(Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#32 /home/luiz/Projects/laravel/docintent/vendor/symfony/console/Application.php(262): Symfony\Component\Console\Application->doRunCommand(Object(Illuminate\Database\Console\Migrations\FreshCommand), Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#33 /home/luiz/Projects/laravel/docintent/vendor/symfony/console/Application.php(145): Symfony\Component\Console\Application->doRun(Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#34 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Console/Application.php(89): Symfony\Component\Console\Application->run(Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#35 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Foundation/Console/Kernel.php(122): Illuminate\Console\Application->run(Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#36 /home/luiz/Projects/laravel/docintent/artisan(37): Illuminate\Foundation\Console\Kernel->handle(Object(Symfony\Component\Console\Input\ArgvInput), Object(Symfony\Component\Console\Output\ConsoleOutput))#37 {main}\"}"

# %%
source.replace('\\', '_')
# Out:
# '{"exception":"[object] (Illuminate_Database_QueryException(code: HY000): SQLSTATE[HY000]: General error: 1215 Cannot add foreign key constraint (SQL: alter table `search_hits` add constraint `search_hits_bot_session_id_foreign` foreign key (`bot_session_id`) references `bot_sessions` (`id`) on delete cascade) at /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php:664, PDOException(code: HY000): SQLSTATE[HY000]: General error: 1215 Cannot add foreign key constraint at /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php:458)[stacktrace]#0 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php(624): Illuminate_Database_Connection->runQueryCallback(\'alter table `se...\', Array, Object(Closure))#1 /home/luiz/Projects/laravel/docintent/vendor/laravel/framework/src/Illuminate/Database/Connection.php(459): Illuminate_Database_Connection->run(\'a
# ...
